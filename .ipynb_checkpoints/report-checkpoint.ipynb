# %% [markdown]
# # Group Project:(draft version)

# %% [markdown]
# Members: Tracy Gan, Zihua Li, Xinya Lu, Matilda Lucas

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# ## II. Analysis

# %% [markdown]
# ### A. Exploratory data analysis

# %%
#load all the libraries
library(car)
library(ggplot2)
library(reshape2)
library(tidyverse)
library(broom)
library(caret)
library(RColorBrewer)
library(leaps)

# %%
# load the dataset
data <- read.csv("dataset.csv")
cat("Figure 1. Preview of the High School Alcoholism and Academic Performance dataset.\n")
head(data, 3)
# Out:
# Figure 1. Preview of the High School Alcoholism and Academic Performance dataset.
#   school sex age address famsize Pstatus Medu Fedu Mjob    Fjob    ⋯ romantic
# 1 GP     F   18  U       GT3     A       4    4    at_home teacher ⋯ no
# 2 GP     F   17  U       GT3     T       1    1    at_home other   ⋯ no
# 3 GP     F   15  U       LE3     T       1    1    at_home other   ⋯ no
#   famrel freetime goout Dalc Walc health absences G1 G2
# 1 4      3        4     1    1    3      4         0 11
# 2 5      3        3     1    1    3      2         9 11
# 3 4      3        2     2    3    3      6        12 13

# %%
# clean the dataset, and store the clean dataset
missing_summary <- sapply(data, function(x) sum(is.na(x)))
data[is.na(data)] <- lapply(data[is.na(data)], function(x) ifelse(is.numeric(x), median(x, na.rm = TRUE), "unknown"))
                            
# Add a new column 'G1_G2_Average' that is the average of G1 and G2
data$G1_G2_Average <- rowMeans(data[c("G1", "G2")], na.rm = TRUE)

# Remove rows where either G1 or G2 is equal to 0
data <- subset(data, G1 != 0 & G2 != 0)
head(data)
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
# 7 GP     M   16  U       LE3     T       2    2    other    other    ⋯ 4
#   freetime goout Dalc Walc health absences G1 G2 G1_G2_Average
# 2 3        3     1    1    3      2         9 11 10.0
# 3 3        2     2    3    3      6        12 13 12.5
# 4 2        2     1    1    5      0        14 14 14.0
# 5 3        2     1    2    5      0        11 13 12.0
# 6 4        2     1    2    5      6        12 12 12.0
# 7 4        4     1    1    3      0        13 12 12.5

# %%
# Distribution histogram of the Average of G1 and G2
ggplot(data, aes(x = G1_G2_Average)) +
  geom_histogram(binwidth = 1, fill = "skyblue", color = "black", alpha = 0.7) +
  labs(title = "Distribution of average of G1 and G2 (First Period Grades)", x = "Average", y = "Count") +
  theme_minimal()
# Out:
# plot without title

# %%
# initialize the model
full_model <- lm(G1_G2_Average ~ .-G1-G2, data = data)
summary(full_model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ . - G1 - G2, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.8037 -1.4276 -0.1096  1.3945  7.5635
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      10.25261    1.61028   6.367 3.83e-10 ***
# schoolMS         -0.97179    0.21946  -4.428 1.13e-05 ***
# sexM             -0.64166    0.20452  -3.137 0.001788 **
# age              -0.01470    0.08141  -0.181 0.856744
# addressU          0.14781    0.21591   0.685 0.493847
# famsizeLE3        0.28564    0.20048   1.425 0.154728
# PstatusT          0.01231    0.28805   0.043 0.965939
# Medu              0.19076    0.12394   1.539 0.124314
# Fedu              0.10750    0.11248   0.956 0.339567
# Mjobhealth        0.25098    0.43903   0.572 0.567750
# Mjobother         0.01770    0.24978   0.071 0.943522
# Mjobservices      0.11691    0.30721   0.381 0.703667
# Mjobteacher       0.37899    0.41381   0.916 0.360106
# Fjobhealth       -0.14772    0.61495  -0.240 0.810249
# Fjobother         0.20345    0.37558   0.542 0.588232
# Fjobservices     -0.08356    0.39431  -0.212 0.832254
# Fjobteacher       1.29793    0.55416   2.342 0.019497 *
# reasonhome        0.35565    0.23220   1.532 0.126131
# reasonother       0.02092    0.30187   0.069 0.944780
# reasonreputation  0.57480    0.24311   2.364 0.018379 *
# guardianmother   -0.36997    0.21750  -1.701 0.089455 .
# guardianother    -0.47210    0.43562  -1.084 0.278908
# traveltime       -0.11027    0.13049  -0.845 0.398415
# studytime         0.40467    0.11401   3.549 0.000416 ***
# schoolsupyes     -1.28452    0.29762  -4.316 1.86e-05 ***
# famsupyes        -0.29869    0.18724  -1.595 0.111184
# paidyes          -0.58100    0.37577  -1.546 0.122590
# activitiesyes     0.25513    0.18332   1.392 0.164528
# nurseryyes        0.01017    0.22189   0.046 0.963444
# higheryes         1.75307    0.31170   5.624 2.85e-08 ***
# internetyes       0.06943    0.22744   0.305 0.760264
# romanticyes      -0.23958    0.18850  -1.271 0.204220
# famrel            0.14371    0.09594   1.498 0.134681
# freetime         -0.11548    0.09168  -1.260 0.208325
# goout            -0.03637    0.08837  -0.412 0.680822
# Dalc             -0.13584    0.12589  -1.079 0.281005
# Walc             -0.04787    0.09769  -0.490 0.624303
# health           -0.09361    0.06344  -1.476 0.140565
# absences         -0.07938    0.02036  -3.899 0.000108 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.175 on 602 degrees of freedom
# Multiple R-squared:  0.3398,	Adjusted R-squared:  0.2981
# F-statistic: 8.154 on 38 and 602 DF,  p-value: < 2.2e-16

# %%
#setup the covariance matrix
cor_matrix <- cor(data[, sapply(data, is.numeric)], use = "complete.obs")
print(cor_matrix)
cor_data <- melt(cor_matrix)
ggplot(cor_data, aes(Var1, Var2, fill = value)) +
  geom_tile(color = "white") +
  scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
                       midpoint = 0, limit = c(-1, 1), space = "Lab", 
                       name = "Correlation") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, vjust = 1, hjust = 1)) +
  coord_fixed() +
  labs(title = "Correlation Heatmap", x = "", y = "")
# Out:
#                        age          Medu         Fedu   traveltime    studytime
# age            1.000000000 -0.1071396643 -0.118042945  0.030845460 -0.003609801
# Medu          -0.107139664  1.0000000000  0.645488866 -0.263098298  0.095676994
# Fedu          -0.118042945  0.6454888661  1.000000000 -0.208830257  0.047933001
# traveltime     0.030845460 -0.2630982982 -0.208830257  1.000000000 -0.065678432
# studytime     -0.003609801  0.0956769936  0.047933001 -0.065678432  1.000000000
# famrel        -0.018093470  0.0243630012  0.021116049 -0.015867835 -0.011391059
# freetime      -0.012852716 -0.0111848460  0.014506300 -0.003951757 -0.068942036
# goout          0.116035103  0.0198809843  0.031051102  0.048263319 -0.080574426
# Dalc           0.141135299  0.0003864622  0.006385022  0.094296846 -0.136228547
# Walc           0.089311042 -0.0077332838  0.048102051  0.057224949 -0.215706201
# health        -0.004586005 -0.0030225857  0.041862757 -0.042960838 -0.055106843
# absences       0.159738070 -0.0127498023  0.024160859 -0.006587480 -0.122906917
# G1            -0.155449594  0.2741140853  0.223265629 -0.157059616  0.260169011
# G2            -0.074440958  0.2710937198  0.217392101 -0.161133433  0.244458242
# G1_G2_Average -0.118157008  0.2801972072  0.226466492 -0.163527384  0.259343365
#                    famrel     freetime        goout          Dalc         Walc
# age           -0.01809347 -0.012852716  0.116035103  0.1411352994  0.089311042
# Medu           0.02436300 -0.011184846  0.019880984  0.0003864622 -0.007733284
# Fedu           0.02111605  0.014506300  0.031051102  0.0063850223  0.048102051
# traveltime    -0.01586784 -0.003951757  0.048263319  0.0942968465  0.057224949
# studytime     -0.01139106 -0.068942036 -0.080574426 -0.1362285466 -0.215706201
# famrel         1.00000000  0.124503330  0.075983707 -0.0785511909 -0.094247472
# freetime       0.12450333  1.000000000  0.340808265  0.1087528896  0.114316559
# goout          0.07598371  0.340808265  1.000000000  0.2447887359  0.387614387
# Dalc          -0.07855119  0.108752890  0.244788736  1.0000000000  0.614743619
# Walc          -0.09424747  0.114316559  0.387614387  0.6147436193  1.000000000
# health         0.11795773  0.095931371 -0.001293722  0.0599377356  0.123362266
# absences      -0.09443038 -0.015644401  0.084241500  0.1782028230  0.161165992
# G1             0.04433530 -0.092045798 -0.081959880 -0.1982203111 -0.163386858
# G2             0.08173959 -0.100206030 -0.101627682 -0.1915872016 -0.166784970
# G1_G2_Average  0.06478857 -0.098802321 -0.094348086 -0.2003333044 -0.169683683
#                     health    absences          G1          G2 G1_G2_Average
# age           -0.004586005  0.15973807 -0.15544959 -0.07444096   -0.11815701
# Medu          -0.003022586 -0.01274980  0.27411409  0.27109372    0.28019721
# Fedu           0.041862757  0.02416086  0.22326563  0.21739210    0.22646649
# traveltime    -0.042960838 -0.00658748 -0.15705962 -0.16113343   -0.16352738
# studytime     -0.055106843 -0.12290692  0.26016901  0.24445824    0.25934337
# famrel         0.117957726 -0.09443038  0.04433530  0.08173959    0.06478857
# freetime       0.095931371 -0.01564440 -0.09204580 -0.10020603   -0.09880232
# goout         -0.001293722  0.08424150 -0.08195988 -0.10162768   -0.09434809
# Dalc           0.059937736  0.17820282 -0.19822031 -0.19158720   -0.20033330
# Walc           0.123362266  0.16116599 -0.16338686 -0.16678497   -0.16968368
# health         1.000000000 -0.03026982 -0.05345435 -0.08984987   -0.07364331
# absences      -0.030269818  1.00000000 -0.16860031 -0.17527086   -0.17672373
# G1            -0.053454352 -0.16860031  1.00000000  0.89307446    0.97291481
# G2            -0.089849872 -0.17527086  0.89307446  1.00000000    0.97288809
# G1_G2_Average -0.073643314 -0.17672373  0.97291481  0.97288809    1.00000000
# plot without title

# %%
# residual plot again fitted values for full model
plot(full_model$fitted.values, residuals(full_model),
     xlab = "Fitted Values",
     ylab = "Residuals",
     main = "Residuals vs Fitted")
abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title “Residuals vs Fitted”

# %%
# QQ-plot for full model
qqnorm(residuals(full_model))
qqline(residuals(full_model), col = "red")
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
# get the VIF values
vif_values <- vif(full_model)
print(vif_values)
# Out:
#                GVIF Df GVIF^(1/(2*Df))
# school     1.468436  1        1.211790
# sex        1.371876  1        1.171271
# age        1.323619  1        1.150486
# address    1.329733  1        1.153141
# famsize    1.139622  1        1.067531
# Pstatus    1.188740  1        1.090293
# Medu       2.670563  1        1.634186
# Fedu       2.074944  1        1.440467
# Mjob       2.586037  4        1.126106
# Fjob       1.879394  4        1.082062
# reason     1.436266  3        1.062199
# guardian   1.426866  2        1.092939
# traveltime 1.294327  1        1.137685
# studytime  1.218453  1        1.103836
# schoolsup  1.123830  1        1.060108
# famsup     1.122169  1        1.059325
# paid       1.093694  1        1.045798
# activities 1.137683  1        1.066622
# nursery    1.066634  1        1.032780
# higher     1.216373  1        1.102893
# internet   1.227334  1        1.107851
# romantic   1.116361  1        1.056580
# famrel     1.119786  1        1.058199
# freetime   1.256851  1        1.121094
# goout      1.442530  1        1.201054
# Dalc       1.830838  1        1.353085
# Walc       2.124320  1        1.457505
# health     1.139805  1        1.067617
# absences   1.215228  1        1.102374

# %%
#split data
data <- 
    data %>% 
    mutate(id = row_number())

training_data <- 
    data %>% 
    slice_sample(prop = 0.70, replace = FALSE)

testing_data <- 
    data %>%
    anti_join(training_data, by = "id") %>%
    select(-"id")

training_data <- 
    training_data %>% 
    select(-"id")

# %%
#backward selection to choose the covariates
your_backward_sel <- regsubsets(
  x = G1_G2_Average ~ .-G1-G2,  
  nvmax = 4,       
  data = training_data,         
  method = "backward"          
)

your_backward_sel

your_bwd_summary <- summary(your_backward_sel)

your_bwd_summary_df <- tibble(
  n_input_variables = 1:4,          
  R2 = your_bwd_summary$rsq,
  RSS = your_bwd_summary$rss,
  ADJ.R2 = your_bwd_summary$adjr2,
  BIC = your_bwd_summary$bic,
  Cp = your_bwd_summary$cp
)

your_bwd_summary_df
your_bwd_summary
# Out:
# Subset selection object
# Call: regsubsets.formula(x = G1_G2_Average ~ . - G1 - G2, nvmax = 4,
#     data = training_data, method = "backward")
# 38 Variables  (and intercept)
#                  Forced in Forced out
# schoolMS             FALSE      FALSE
# sexM                 FALSE      FALSE
# age                  FALSE      FALSE
# addressU             FALSE      FALSE
# famsizeLE3           FALSE      FALSE
# PstatusT             FALSE      FALSE
# Medu                 FALSE      FALSE
# Fedu                 FALSE      FALSE
# Mjobhealth           FALSE      FALSE
# Mjobother            FALSE      FALSE
# Mjobservices         FALSE      FALSE
# Mjobteacher          FALSE      FALSE
# Fjobhealth           FALSE      FALSE
# Fjobother            FALSE      FALSE
# Fjobservices         FALSE      FALSE
# Fjobteacher          FALSE      FALSE
# reasonhome           FALSE      FALSE
# reasonother          FALSE      FALSE
# reasonreputation     FALSE      FALSE
# guardianmother       FALSE      FALSE
# guardianother        FALSE      FALSE
# traveltime           FALSE      FALSE
# studytime            FALSE      FALSE
# schoolsupyes         FALSE      FALSE
# famsupyes            FALSE      FALSE
# paidyes              FALSE      FALSE
# activitiesyes        FALSE      FALSE
# nurseryyes           FALSE      FALSE
# higheryes            FALSE      FALSE
# internetyes          FALSE      FALSE
# romanticyes          FALSE      FALSE
# famrel               FALSE      FALSE
# freetime             FALSE      FALSE
# goout                FALSE      FALSE
# Dalc                 FALSE      FALSE
# Walc                 FALSE      FALSE
# health               FALSE      FALSE
# absences             FALSE      FALSE
# 1 subsets of each size up to 4
# Selection Algorithm: backward
#   n_input_variables R2        RSS      ADJ.R2    BIC       Cp
# 1 1                 0.1041358 2569.785 0.1021271 -37.05536 98.22977
# 2 2                 0.1506741 2436.289 0.1468569 -54.84954 72.06203
# 3 3                 0.1876441 2330.241 0.1821552 -68.68272 51.68562
# 4 4                 0.2069856 2274.760 0.1998252 -73.37344 41.97902
# Subset selection object
# Call: regsubsets.formula(x = G1_G2_Average ~ . - G1 - G2, nvmax = 4,
#     data = training_data, method = "backward")
# 38 Variables  (and intercept)
#                  Forced in Forced out
# schoolMS             FALSE      FALSE
# sexM                 FALSE      FALSE
# age                  FALSE      FALSE
# addressU             FALSE      FALSE
# famsizeLE3           FALSE      FALSE
# PstatusT             FALSE      FALSE
# Medu                 FALSE      FALSE
# Fedu                 FALSE      FALSE
# Mjobhealth           FALSE      FALSE
# Mjobother            FALSE      FALSE
# Mjobservices         FALSE      FALSE
# Mjobteacher          FALSE      FALSE
# Fjobhealth           FALSE      FALSE
# Fjobother            FALSE      FALSE
# Fjobservices         FALSE      FALSE
# Fjobteacher          FALSE      FALSE
# reasonhome           FALSE      FALSE
# reasonother          FALSE      FALSE
# reasonreputation     FALSE      FALSE
# guardianmother       FALSE      FALSE
# guardianother        FALSE      FALSE
# traveltime           FALSE      FALSE
# studytime            FALSE      FALSE
# schoolsupyes         FALSE      FALSE
# famsupyes            FALSE      FALSE
# paidyes              FALSE      FALSE
# activitiesyes        FALSE      FALSE
# nurseryyes           FALSE      FALSE
# higheryes            FALSE      FALSE
# internetyes          FALSE      FALSE
# romanticyes          FALSE      FALSE
# famrel               FALSE      FALSE
# freetime             FALSE      FALSE
# goout                FALSE      FALSE
# Dalc                 FALSE      FALSE
# Walc                 FALSE      FALSE
# health               FALSE      FALSE
# absences             FALSE      FALSE
# 1 subsets of each size up to 4
# Selection Algorithm: backward
#          schoolMS sexM age addressU famsizeLE3 PstatusT Medu Fedu Mjobhealth
# 1  ( 1 ) " "      " "  " " " "      " "        " "      " "  " "  " "
# 2  ( 1 ) "*"      " "  " " " "      " "        " "      " "  " "  " "
# 3  ( 1 ) "*"      " "  " " " "      " "        " "      " "  " "  " "
# 4  ( 1 ) "*"      " "  " " " "      " "        " "      " "  " "  " "
#          Mjobother Mjobservices Mjobteacher Fjobhealth Fjobother Fjobservices
# 1  ( 1 ) " "       " "          " "         " "        " "       " "
# 2  ( 1 ) " "       " "          " "         " "        " "       " "
# 3  ( 1 ) " "       " "          " "         " "        " "       " "
# 4  ( 1 ) " "       " "          " "         " "        " "       " "
#          Fjobteacher reasonhome reasonother reasonreputation guardianmother
# 1  ( 1 ) " "         " "        " "         " "              " "
# 2  ( 1 ) " "         " "        " "         " "              " "
# 3  ( 1 ) " "         " "        " "         " "              " "
# 4  ( 1 ) "*"         " "        " "         " "              " "
#          guardianother traveltime studytime schoolsupyes famsupyes paidyes
# 1  ( 1 ) " "           " "        " "       " "          " "       " "
# 2  ( 1 ) " "           " "        " "       " "          " "       " "
# 3  ( 1 ) " "           " "        " "       " "          " "       " "
# 4  ( 1 ) " "           " "        " "       " "          " "       " "
#          activitiesyes nurseryyes higheryes internetyes romanticyes famrel
# 1  ( 1 ) " "           " "        "*"       " "         " "         " "
# 2  ( 1 ) " "           " "        "*"       " "         " "         " "
# 3  ( 1 ) " "           " "        "*"       " "         " "         " "
# 4  ( 1 ) " "           " "        "*"       " "         " "         " "
#          freetime goout Dalc Walc health absences
# 1  ( 1 ) " "      " "   " "  " "  " "    " "
# 2  ( 1 ) " "      " "   " "  " "  " "    " "
# 3  ( 1 ) " "      " "   " "  " "  " "    "*"
# 4  ( 1 ) " "      " "   " "  " "  " "    "*"

# %% [markdown]
# We will use student's school (school), mother's education level (Medu) , individual desire to purse a degree or not (higher), and number of school absences (absence) as our explantory variables

# %%
# linear model with no transformation
model <- lm(G1_G2_Average ~ school + Medu + higher + absences, data = testing_data)
summary(model)
tidy(model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ school + Medu + higher + absences,
#     data = testing_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3757 -1.5512 -0.3599  1.4338  7.4593
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.90680    0.69350  12.843  < 2e-16 ***
# schoolMS    -1.31927    0.38814  -3.399 0.000826 ***
# Medu         0.50525    0.14964   3.376 0.000892 ***
# higheryes    2.44789    0.59086   4.143 5.18e-05 ***
# absences    -0.07343    0.03745  -1.961 0.051371 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.366 on 188 degrees of freedom
# Multiple R-squared:  0.2688,	Adjusted R-squared:  0.2532
# F-statistic: 17.28 on 4 and 188 DF,  p-value: 4.355e-12
#   term        estimate    std.error  statistic p.value
# 1 (Intercept)  8.90679815 0.69349703 12.843311 1.631623e-27
# 2 schoolMS    -1.31926664 0.38814071 -3.398939 8.259050e-04
# 3 Medu         0.50524856 0.14963748  3.376484 8.921098e-04
# 4 higheryes    2.44789447 0.59086183  4.142922 5.178444e-05
# 5 absences    -0.07342684 0.03744604 -1.960871 5.137117e-02

# %%
qqnorm(residuals(model))
qqline(residuals(model), col = "red")
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
plot(model$fitted.values, residuals(model), 
     xlab = "Fitted Values", 
     ylab = "Residuals", 
     main = "Residual Plot")
abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title “Residual Plot”

# %%
# linear model with log transformation
model2 <- lm(log(G1_G2_Average) ~ school + Medu + higher + absences, data = testing_data)
summary(model)
tidy(model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ school + Medu + higher + absences,
#     data = testing_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.3757 -1.5512 -0.3599  1.4338  7.4593
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.90680    0.69350  12.843  < 2e-16 ***
# schoolMS    -1.31927    0.38814  -3.399 0.000826 ***
# Medu         0.50525    0.14964   3.376 0.000892 ***
# higheryes    2.44789    0.59086   4.143 5.18e-05 ***
# absences    -0.07343    0.03745  -1.961 0.051371 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.366 on 188 degrees of freedom
# Multiple R-squared:  0.2688,	Adjusted R-squared:  0.2532
# F-statistic: 17.28 on 4 and 188 DF,  p-value: 4.355e-12
#   term        estimate    std.error  statistic p.value
# 1 (Intercept)  8.90679815 0.69349703 12.843311 1.631623e-27
# 2 schoolMS    -1.31926664 0.38814071 -3.398939 8.259050e-04
# 3 Medu         0.50524856 0.14963748  3.376484 8.921098e-04
# 4 higheryes    2.44789447 0.59086183  4.142922 5.178444e-05
# 5 absences    -0.07342684 0.03744604 -1.960871 5.137117e-02

# %%
plot(model2$fitted.values, residuals(model2), 
     xlab = "Fitted Values", 
     ylab = "Residuals", 
     main = "Residual Plot")
abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title “Residual Plot”

# %% [markdown]
# ## III. Conclusion

# %% [markdown]
# ## IV. Appendix

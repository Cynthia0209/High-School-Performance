# %% [markdown]
# # Group Project:(draft version)

# %% [markdown]
# Members: Tracy Gan, Zihua Li, Xinya Lu, Matilda Lucas

# %% [markdown]
# ## I. Introduction

# %% [markdown]
# ## II. Analysis

# %% [markdown]
# ### A. Exploratory data analysis

# %%
#load all the libraries
library(car)
library(ggplot2)
library(reshape2)
library(tidyverse)
library(broom)
library(caret)
library(RColorBrewer)
library(leaps)

# %% [markdown]
# In our analysis, we aim to model student performance as the response variable. The initial dataset includes performance scores from two periods, G1 and G2. However, some students have a score of zero in one of these periods, indicating they were absent. To ensure the accuracy of our analysis, we created a new variable, G1_G2_Average, which represents the average performance across both periods. We also removed data for students who were absent in one period, as their absences should not influence the measure of student performance.

# %%
# load the dataset
data <- read.csv("dataset.csv")
head(data, 3)
cat("Table 1. Preview of the High School Alcoholism and Academic Performance dataset.\n")
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob    Fjob    ⋯ romantic
# 1 GP     F   18  U       GT3     A       4    4    at_home teacher ⋯ no
# 2 GP     F   17  U       GT3     T       1    1    at_home other   ⋯ no
# 3 GP     F   15  U       LE3     T       1    1    at_home other   ⋯ no
#   famrel freetime goout Dalc Walc health absences G1 G2
# 1 4      3        4     1    1    3      4         0 11
# 2 5      3        3     1    1    3      2         9 11
# 3 4      3        2     2    3    3      6        12 13
# Table 1. Preview of the High School Alcoholism and Academic Performance dataset.

# %%
# clean the dataset, and store the clean dataset
missing_summary <- sapply(data, function(x) sum(is.na(x)))
data[is.na(data)] <- lapply(data[is.na(data)], function(x) ifelse(is.numeric(x), median(x, na.rm = TRUE), "unknown"))
                            
# Add a new column 'G1_G2_Average' that is the average of G1 and G2
data$G1_G2_Average <- rowMeans(data[c("G1", "G2")], na.rm = TRUE)

# Remove rows where either G1 or G2 is equal to 0
data <- subset(data, G1 != 0 & G2 != 0)
head(data)
cat("Table 2. Preview of the cleaned High School Alcoholism and Academic Performance dataset.\n")
# Out:
#   school sex age address famsize Pstatus Medu Fedu Mjob     Fjob     ⋯ famrel
# 2 GP     F   17  U       GT3     T       1    1    at_home  other    ⋯ 5
# 3 GP     F   15  U       LE3     T       1    1    at_home  other    ⋯ 4
# 4 GP     F   15  U       GT3     T       4    2    health   services ⋯ 3
# 5 GP     F   16  U       GT3     T       3    3    other    other    ⋯ 4
# 6 GP     M   16  U       LE3     T       4    3    services other    ⋯ 5
# 7 GP     M   16  U       LE3     T       2    2    other    other    ⋯ 4
#   freetime goout Dalc Walc health absences G1 G2 G1_G2_Average
# 2 3        3     1    1    3      2         9 11 10.0
# 3 3        2     2    3    3      6        12 13 12.5
# 4 2        2     1    1    5      0        14 14 14.0
# 5 3        2     1    2    5      0        11 13 12.0
# 6 4        2     1    2    5      6        12 12 12.0
# 7 4        4     1    1    3      0        13 12 12.5
# Table 2. Preview of the cleaned High School Alcoholism and Academic Performance dataset.

# %%
# Distribution histogram of the Average of G1 and G2
hist <- ggplot(data, aes(x = G1_G2_Average)) +
  geom_histogram(binwidth = 1, fill = "skyblue", color = "black", alpha = 0.7) +
  labs(title = "Distribution of average of G1 and G2", x = "Average", y = "Count") +
  theme_minimal()
hist
cat("Figure 1. Distribution of average of G1 and G2.\n")
# Out:
# Figure 1. Distribution of average of G1 and G2.
# plot without title

# %% [markdown]
# Figure 1 illustrates how the average grades are continuously distributed. We can see most grades concentrated around the center and there is no outliers or invalid data after we clean our dataset.

# %%
# initialize the model
full_model <- lm(G1_G2_Average ~ .-G1-G2, data = data)
summary(full_model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ . - G1 - G2, data = data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -7.102 -1.430 -0.067  1.236  7.484
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      13.079267   1.889717   6.921 1.15e-11 ***
# schoolMS         -2.007755   0.427723  -4.694 3.32e-06 ***
# sexM             -0.602099   0.203838  -2.954 0.003261 **
# age              -0.231594   0.111735  -2.073 0.038625 *
# addressU          0.190954   0.215221   0.887 0.375302
# famsizeLE3        0.283654   0.199332   1.423 0.155249
# PstatusT          0.047311   0.286672   0.165 0.868972
# Medu              0.201563   0.123297   1.635 0.102620
# Fedu              0.102077   0.111851   0.913 0.361806
# Mjobhealth        0.218443   0.436676   0.500 0.617089
# Mjobother         0.020878   0.248358   0.084 0.933032
# Mjobservices      0.089412   0.305613   0.293 0.769955
# Mjobteacher       0.300299   0.412397   0.728 0.466787
# Fjobhealth       -0.018390   0.613162  -0.030 0.976083
# Fjobother         0.258421   0.373950   0.691 0.489795
# Fjobservices     -0.025408   0.392603  -0.065 0.948421
# Fjobteacher       1.382011   0.551807   2.505 0.012525 *
# reasonhome        0.361462   0.230883   1.566 0.117977
# reasonother       0.071456   0.300683   0.238 0.812237
# reasonreputation  0.567625   0.241738   2.348 0.019192 *
# guardianmother   -0.348034   0.216399  -1.608 0.108294
# guardianother    -0.340445   0.435648  -0.781 0.434835
# traveltime       -0.119048   0.129786  -0.917 0.359371
# studytime         0.394093   0.113425   3.474 0.000549 ***
# schoolsupyes     -1.173195   0.298549  -3.930 9.50e-05 ***
# famsupyes        -0.256408   0.186777  -1.373 0.170327
# paidyes          -0.561274   0.373690  -1.502 0.133628
# activitiesyes     0.279265   0.182479   1.530 0.126445
# nurseryyes        0.034402   0.220796   0.156 0.876234
# higheryes         1.614582   0.313794   5.145 3.62e-07 ***
# internetyes       0.039710   0.226385   0.175 0.860818
# romanticyes      -0.258681   0.187542  -1.379 0.168308
# famrel            0.135757   0.095438   1.422 0.155408
# freetime         -0.095594   0.091431  -1.046 0.296197
# goout            -0.046912   0.087944  -0.533 0.593933
# Dalc             -0.116474   0.125364  -0.929 0.353217
# Walc             -0.060172   0.097233  -0.619 0.536255
# health           -0.090346   0.063085  -1.432 0.152623
# absences         -0.077144   0.020261  -3.808 0.000155 ***
# id                0.003408   0.001210   2.816 0.005021 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.162 on 601 degrees of freedom
# Multiple R-squared:  0.3484,	Adjusted R-squared:  0.3061
# F-statistic:  8.24 on 39 and 601 DF,  p-value: < 2.2e-16

# %%
#setup the covariance matrix
cor_matrix <- cor(data[, sapply(data, is.numeric)], use = "complete.obs")
#print(cor_matrix)
cor_data <- melt(cor_matrix)
ggplot(cor_data, aes(Var1, Var2, fill = value)) +
  geom_tile(color = "white") +
  scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
                       midpoint = 0, limit = c(-1, 1), space = "Lab", 
                       name = "Correlation") +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, vjust = 1, hjust = 1)) +
  coord_fixed() +
  labs(title = "Correlation Heatmap", x = "", y = "")
cat("\nFigure 2. Correlation heatmap.\n")
# Out:
# Figure 2. Correlation heatmap.
# plot without title

# %% [markdown]
# Figure 2 uses a color gradient to represent the strength and direction of correlations. We can see Medu, Fedu, and studytime might has a stronger correlation with G1_G2_Average.

# %%
# residual plot again fitted values for full model
plot(full_model$fitted.values, residuals(full_model),
     xlab = "Fitted Values",
     ylab = "Residuals",
     main = "Residuals vs Fitted")
abline(h = 0, col = "red", lty = 2)
cat("\nFigure 3. Residual plot for full model.\n")
# Out:
# Figure 3. Residual plot for full model.
# Plot with title “Residuals vs Fitted”

# %% [markdown]
# Based on Figure 3, the assumption of constant variance might be violated, as the plot appears to have a funnel-shaped pattern.

# %%
# QQ-plot for full model
qqnorm(residuals(full_model))
qqline(residuals(full_model), col = "red")
cat("\nFigure 4. Q-Q plot for full model.\n")
# Out:
# Figure 4. Q-Q plot for full model.
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# Based on Figure 4, the residuals of the full model appear to follow a normal distribution.

# %%
# get the VIF values
vif_values <- vif(full_model)
print(vif_values)
# Out:
#                GVIF Df GVIF^(1/(2*Df))
# school     5.642181  1        2.375328
# sex        1.378422  1        1.174062
# age        2.521827  1        1.588026
# address    1.336504  1        1.156073
# famsize    1.139636  1        1.067537
# Pstatus    1.190979  1        1.091320
# Medu       2.673151  1        1.634977
# Fedu       2.075559  1        1.440680
# Mjob       2.603515  4        1.127055
# Fjob       1.890960  4        1.082892
# reason     1.442244  3        1.062934
# guardian   1.443597  2        1.096129
# traveltime 1.295073  1        1.138013
# studytime  1.219790  1        1.104441
# schoolsup  1.143886  1        1.069526
# famsup     1.129470  1        1.062765
# paid       1.094079  1        1.045982
# activities 1.140198  1        1.067800
# nursery    1.068256  1        1.033564
# higher     1.247001  1        1.116692
# internet   1.230007  1        1.109057
# romantic   1.117824  1        1.057272
# famrel     1.120768  1        1.058663
# freetime   1.264390  1        1.124451
# goout      1.445149  1        1.202144
# Dalc       1.836366  1        1.355126
# Walc       2.128616  1        1.458978
# health     1.140190  1        1.067797
# absences   1.217097  1        1.103221
# id         6.877476  1        2.622494

# %% [markdown]
# VIF quantifies how much multicollinearity inflates the variance of a regression coefficient. From the calculated VIF values, no variable exceeds a value of 5, suggesting that multicollinearity is unlikely to be a concern in the model.

# %%
#split data
data <- 
    data %>% 
    mutate(id = row_number())

training_data <- 
    data %>% 
    slice_sample(prop = 0.70, replace = FALSE)

testing_data <- 
    data %>%
    anti_join(training_data, by = "id") %>%
    select(-"id")

training_data <- 
    training_data %>% 
    select(-"id")

# %% [markdown]
# To select the most appropriate covariates for our model, we will perform backward selection. First, we will split the data into a training set and a testing set. The training set will be used for the backward selection process, while the testing set will be used to build and evaluate the final model.

# %%
#backward selection to choose the covariates
your_backward_sel <- regsubsets(
  x = G1_G2_Average ~ .-G1-G2,  
  nvmax = 4,       
  data = training_data,         
  method = "backward"          
)

your_backward_sel

your_bwd_summary <- summary(your_backward_sel)

your_bwd_summary_df <- tibble(
  n_input_variables = 1:4,          
  R2 = your_bwd_summary$rsq,
  RSS = your_bwd_summary$rss,
  ADJ.R2 = your_bwd_summary$adjr2,
  BIC = your_bwd_summary$bic,
  Cp = your_bwd_summary$cp
)

your_bwd_summary_df
your_bwd_summary
# Out:
# Subset selection object
# Call: regsubsets.formula(x = G1_G2_Average ~ . - G1 - G2, nvmax = 4,
#     data = training_data, method = "backward")
# 38 Variables  (and intercept)
#                  Forced in Forced out
# schoolMS             FALSE      FALSE
# sexM                 FALSE      FALSE
# age                  FALSE      FALSE
# addressU             FALSE      FALSE
# famsizeLE3           FALSE      FALSE
# PstatusT             FALSE      FALSE
# Medu                 FALSE      FALSE
# Fedu                 FALSE      FALSE
# Mjobhealth           FALSE      FALSE
# Mjobother            FALSE      FALSE
# Mjobservices         FALSE      FALSE
# Mjobteacher          FALSE      FALSE
# Fjobhealth           FALSE      FALSE
# Fjobother            FALSE      FALSE
# Fjobservices         FALSE      FALSE
# Fjobteacher          FALSE      FALSE
# reasonhome           FALSE      FALSE
# reasonother          FALSE      FALSE
# reasonreputation     FALSE      FALSE
# guardianmother       FALSE      FALSE
# guardianother        FALSE      FALSE
# traveltime           FALSE      FALSE
# studytime            FALSE      FALSE
# schoolsupyes         FALSE      FALSE
# famsupyes            FALSE      FALSE
# paidyes              FALSE      FALSE
# activitiesyes        FALSE      FALSE
# nurseryyes           FALSE      FALSE
# higheryes            FALSE      FALSE
# internetyes          FALSE      FALSE
# romanticyes          FALSE      FALSE
# famrel               FALSE      FALSE
# freetime             FALSE      FALSE
# goout                FALSE      FALSE
# Dalc                 FALSE      FALSE
# Walc                 FALSE      FALSE
# health               FALSE      FALSE
# absences             FALSE      FALSE
# 1 subsets of each size up to 4
# Selection Algorithm: backward
#   n_input_variables R2        RSS      ADJ.R2    BIC        Cp
# 1 1                 0.1238058 2704.799 0.1218412  -47.00145 123.99392
# 2 2                 0.1987049 2473.587 0.1951036  -80.92928  77.44044
# 3 3                 0.2310203 2373.829 0.2258245  -93.26629  58.49195
# 4 4                 0.2614052 2280.032 0.2547361 -105.22261  40.79496
# Subset selection object
# Call: regsubsets.formula(x = G1_G2_Average ~ . - G1 - G2, nvmax = 4,
#     data = training_data, method = "backward")
# 38 Variables  (and intercept)
#                  Forced in Forced out
# schoolMS             FALSE      FALSE
# sexM                 FALSE      FALSE
# age                  FALSE      FALSE
# addressU             FALSE      FALSE
# famsizeLE3           FALSE      FALSE
# PstatusT             FALSE      FALSE
# Medu                 FALSE      FALSE
# Fedu                 FALSE      FALSE
# Mjobhealth           FALSE      FALSE
# Mjobother            FALSE      FALSE
# Mjobservices         FALSE      FALSE
# Mjobteacher          FALSE      FALSE
# Fjobhealth           FALSE      FALSE
# Fjobother            FALSE      FALSE
# Fjobservices         FALSE      FALSE
# Fjobteacher          FALSE      FALSE
# reasonhome           FALSE      FALSE
# reasonother          FALSE      FALSE
# reasonreputation     FALSE      FALSE
# guardianmother       FALSE      FALSE
# guardianother        FALSE      FALSE
# traveltime           FALSE      FALSE
# studytime            FALSE      FALSE
# schoolsupyes         FALSE      FALSE
# famsupyes            FALSE      FALSE
# paidyes              FALSE      FALSE
# activitiesyes        FALSE      FALSE
# nurseryyes           FALSE      FALSE
# higheryes            FALSE      FALSE
# internetyes          FALSE      FALSE
# romanticyes          FALSE      FALSE
# famrel               FALSE      FALSE
# freetime             FALSE      FALSE
# goout                FALSE      FALSE
# Dalc                 FALSE      FALSE
# Walc                 FALSE      FALSE
# health               FALSE      FALSE
# absences             FALSE      FALSE
# 1 subsets of each size up to 4
# Selection Algorithm: backward
#          schoolMS sexM age addressU famsizeLE3 PstatusT Medu Fedu Mjobhealth
# 1  ( 1 ) " "      " "  " " " "      " "        " "      " "  " "  " "
# 2  ( 1 ) " "      " "  " " " "      " "        " "      "*"  " "  " "
# 3  ( 1 ) "*"      " "  " " " "      " "        " "      "*"  " "  " "
# 4  ( 1 ) "*"      " "  " " " "      " "        " "      "*"  " "  " "
#          Mjobother Mjobservices Mjobteacher Fjobhealth Fjobother Fjobservices
# 1  ( 1 ) " "       " "          " "         " "        " "       " "
# 2  ( 1 ) " "       " "          " "         " "        " "       " "
# 3  ( 1 ) " "       " "          " "         " "        " "       " "
# 4  ( 1 ) " "       " "          " "         " "        " "       " "
#          Fjobteacher reasonhome reasonother reasonreputation guardianmother
# 1  ( 1 ) " "         " "        " "         " "              " "
# 2  ( 1 ) " "         " "        " "         " "              " "
# 3  ( 1 ) " "         " "        " "         " "              " "
# 4  ( 1 ) " "         " "        " "         " "              " "
#          guardianother traveltime studytime schoolsupyes famsupyes paidyes
# 1  ( 1 ) " "           " "        " "       " "          " "       " "
# 2  ( 1 ) " "           " "        " "       " "          " "       " "
# 3  ( 1 ) " "           " "        " "       " "          " "       " "
# 4  ( 1 ) " "           " "        " "       " "          " "       " "
#          activitiesyes nurseryyes higheryes internetyes romanticyes famrel
# 1  ( 1 ) " "           " "        "*"       " "         " "         " "
# 2  ( 1 ) " "           " "        "*"       " "         " "         " "
# 3  ( 1 ) " "           " "        "*"       " "         " "         " "
# 4  ( 1 ) " "           " "        "*"       " "         " "         " "
#          freetime goout Dalc Walc health absences
# 1  ( 1 ) " "      " "   " "  " "  " "    " "
# 2  ( 1 ) " "      " "   " "  " "  " "    " "
# 3  ( 1 ) " "      " "   " "  " "  " "    " "
# 4  ( 1 ) " "      " "   "*"  " "  " "    " "

# %% [markdown]
# Based on the result of backward selection, we will use student's school (school), mother's education level (Medu) , individual desire to purse a degree or not (higher), and number of school absences (absence) as our explantory variables

# %%
# linear model with no transformation
model <- lm(G1_G2_Average ~ school + Medu + higher + absences, data = testing_data)
summary(model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ school + Medu + higher + absences,
#     data = testing_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8354 -1.4642 -0.0867  1.3346  6.4601
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.44692    0.69202  15.096  < 2e-16 ***
# schoolMS    -1.13534    0.35218  -3.224 0.001492 **
# Medu         0.09428    0.14955   0.630 0.529194
# higheryes    2.13406    0.60026   3.555 0.000478 ***
# absences    -0.13211    0.04013  -3.292 0.001187 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.302 on 188 degrees of freedom
# Multiple R-squared:  0.1846,	Adjusted R-squared:  0.1672
# F-statistic: 10.64 on 4 and 188 DF,  p-value: 8.591e-08

# %% [markdown]
# Then we create a linear model between the avarage student performance and the four covariates that we choose.

# %%
qqnorm(residuals(model))
qqline(residuals(model), col = "red")
cat("\nFigure 5. Q-Q plot for actual model.\n")
# Out:
# Figure 5. Q-Q plot for actual model.
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# Based on Figure 5, the residuals of our actual model appear to follow a normal distribution.

# %%
plot(model$fitted.values, residuals(model), 
     xlab = "Fitted Values", 
     ylab = "Residuals", 
     main = "Residual Plot")
abline(h = 0, col = "red", lty = 2)
cat("\nFigure 6. Residual plot for actual model.\n")
# Out:
# Figure 6. Residual plot for actual model.
# Plot with title “Residual Plot”

# %% [markdown]
# Based on Figure 6, the residual plot for the fitted model indicates that the constant variance assumption is likely violated. To address this issue, we decided to apply a log transformation to the fitted values.

# %%
# linear model with log transformation
model2 <- lm(log(G1_G2_Average) ~ school + Medu + higher + absences, data = testing_data)
summary(model)
# Out:
# Call:
# lm(formula = G1_G2_Average ~ school + Medu + higher + absences,
#     data = testing_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.8354 -1.4642 -0.0867  1.3346  6.4601
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.44692    0.69202  15.096  < 2e-16 ***
# schoolMS    -1.13534    0.35218  -3.224 0.001492 **
# Medu         0.09428    0.14955   0.630 0.529194
# higheryes    2.13406    0.60026   3.555 0.000478 ***
# absences    -0.13211    0.04013  -3.292 0.001187 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.302 on 188 degrees of freedom
# Multiple R-squared:  0.1846,	Adjusted R-squared:  0.1672
# F-statistic: 10.64 on 4 and 188 DF,  p-value: 8.591e-08

# %%
plot(model2$fitted.values, residuals(model2), 
     xlab = "Fitted Values", 
     ylab = "Residuals", 
     main = "Residual Plot")
abline(h = 0, col = "red", lty = 2)
cat("\nFigure 7. Residual plot for log-transformed model.\n")
# Out:
# Figure 7. Residual plot for log-transformed model.
# Plot with title “Residual Plot”

# %% [markdown]
# After applying the log transformation to the model, the model fit improved significantly. The new residual plot shows that the residuals are more randomly scattered around the zero line, indicating a better fit.

# %% [markdown]
# ## III. Conclusion

# %% [markdown]
# ## IV. Appendix
